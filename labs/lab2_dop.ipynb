# %% [markdown]
# <a href="https://colab.research.google.com/github/slavcho-k/vnp_labs/blob/master/lab2_dop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Copy of airline_passenger_satisfaction (1).csv')
df
# Out:
#             id  Gender   Customer Type   Age   Type of Travel     Class  \
# 0        70172    Male  Loyal Customer  13.0  Personal Travel  Eco Plus
# 1         5047    Male        Customer  25.0  Business travel  Business
# 2       110028  Female  Loyal Customer  26.0  Business travel  Business
# 3        24026  Female  Loyal Customer  25.0  Business travel  Business
# 4       119299    Male  Loyal Customer  61.0  Business travel  Business
# ...        ...     ...             ...   ...              ...       ...
# 129875   78463    Male        Customer  34.0  Business travel  Business
# 129876   71167    Male  Loyal Customer  23.0  Business travel  Business
# 129877   37675  Female  Loyal Customer  17.0  Personal Travel       Eco
# 129878   90086    Male  Loyal Customer  14.0  Business travel  Business
# 129879   34799  Female  Loyal Customer  42.0  Personal Travel       Eco
#
#         Flight Distance  Inflight wifi service  \
# 0                 460.0                    3.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   id                                 129880 non-null  int64
#  1   Gender                             129876 non-null  object
#  2   Customer Type                      129860 non-null  object
#  3   Age                                129863 non-null  float64
#  4   Type of Travel                     129846 non-null  object
#  5   Class                              129862 non-null  object
#  6   Flight Distance                    129852 non-null  float64
#  7   Inflight wifi service              129871 non-null  float64
#  8   Departure/Arrival time convenient  129854 non-null  float64
#  9   Ease of Online booking             129866 non-null  float64
#  10  Gate location                      129865 non-null  float64
# ...

# %%
missing_values_count = df.isnull().sum()
missing_values_percentage = 100 * missing_values_count / len(df)
missing_values_percentage
# Out:
# id                                   0.000000
# Gender                               0.003080
# Customer Type                        0.015399
# Age                                  0.013089
# Type of Travel                       0.026178
# Class                                0.013859
# Flight Distance                      0.021558
# Inflight wifi service                0.006929
# Departure/Arrival time convenient    0.020018
# Ease of Online booking               0.010779
# Gate location                        0.011549
# Food and drink                       0.016169
# Online boarding                      0.011549
# Seat comfort                         0.085464
# Inflight entertainment               0.007699
# On-board service                     0.007699
# Leg room service                     0.034647
# Baggage handling                     0.010779
# Checkin service                      0.020018
# Inflight service                     0.007699
# ...

# %%
# missing = pd.concat([missing_values_count, missing_values_percentage], axis=1)
# missing.columns = ['# of missing values', '% of missing values']
# missing

# %%
import matplotlib.pyplot as plt
import numpy as np
# #handle missing age
# df_copy = df.copy()
# df_copy['Age'].mean()
# df_copy.dropna(subset=['Age'], how='any', inplace=True)
# df_copy.isnull().sum()
# plt.hist(df['Age'], color='lightgreen', ec='black')

# %%
df_copy = df.copy()
missing_mask = df_copy.select_dtypes(include=[np.number]).columns
missing_mask
# Out:
# Index(['id', 'Age', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes',
#        'Arrival Delay in Minutes'],
#       dtype='object')

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import KNNImputer

categorical_cols = df_copy.select_dtypes(exclude=[np.number]).columns.values.tolist()
num_cols = df_copy.select_dtypes(include=[np.number]).columns.values.tolist()

for c in categorical_cols:
  df_copy[c].fillna(df[c].value_counts().index[0], inplace=True)


k = 5
scaler = MinMaxScaler()

for n in num_cols:
  df_copy[n] = scaler.fit_transform(df_copy[n].to_numpy().reshape(-1, 1))
  imputer = KNNImputer(n_neighbors=k)
  df_copy[n] = imputer.fit_transform(df_copy[n].to_numpy().reshape(-1, 1))

df_copy
# Out:
#               id  Gender   Customer Type       Age   Type of Travel     Class  \
# 0       0.540280    Male  Loyal Customer  0.076923  Personal Travel  Eco Plus
# 1       0.038852    Male        Customer  0.230769  Business travel  Business
# 2       0.847150  Female  Loyal Customer  0.243590  Business travel  Business
# 3       0.184980  Female  Loyal Customer  0.230769  Business travel  Business
# 4       0.918532    Male  Loyal Customer  0.692308  Business travel  Business
# ...          ...     ...             ...       ...              ...       ...
# 129875  0.604116    Male        Customer  0.346154  Business travel  Business
# 129876  0.547941    Male  Loyal Customer  0.205128  Business travel  Business
# 129877  0.290070  Female  Loyal Customer  0.128205  Personal Travel       Eco
# 129878  0.693607    Male  Loyal Customer  0.089744  Business travel  Business
# 129879  0.267926  Female  Loyal Customer  0.448718  Personal Travel       Eco
#
# ...

# %%
from sklearn.model_selection import train_test_split

df['satisfaction'].replace(['satisfied', 'neutral or dissatisfied'],
                        [0, 1], inplace=True)

for c in categorical_cols:
    number = preprocessing.LabelEncoder()
    src = c;
    df_copy[c] = number.fit_transform(df_copy[src])

X_train, X_test, y_train, y_test = train_test_split(df_copy, df["satisfaction"], test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn import preprocessing
from sklearn.metrics import accuracy_score, classification_report

scaler = StandardScaler()

for i in range(1, 10):
  X_train_scaled = scaler.fit_transform(X_train)
  X_test_scaled = scaler.transform(X_test)
  knn_classifier = KNeighborsClassifier(n_neighbors=i)
  knn_classifier.fit(X_train_scaled, y_train)
  y_pred = knn_classifier.predict(X_test_scaled)
  accuracy = accuracy_score(y_test, y_pred)
  # print('for' + i)
  print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     11207
#            1       0.99      1.00      1.00     14769
#
#     accuracy                           1.00     25976
#    macro avg       1.00      1.00      1.00     25976
# weighted avg       1.00      1.00      1.00     25976
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     11207
#            1       1.00      1.00      1.00     14769
#
#     accuracy                           1.00     25976
#    macro avg       1.00      1.00      1.00     25976
# weighted avg       1.00      1.00      1.00     25976
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     11207
#            1       0.99      1.00      1.00     14769
#
#     accuracy                           1.00     25976
#    macro avg       1.00      1.00      1.00     25976
# ...

# %%
# from sklearn.metrics import accuracy_score, classification_report

# y_pred = knn_classifier.predict(X_test_scaled)

# accuracy = accuracy_score(y_test, y_pred)
# print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     11207
#            1       0.99      1.00      1.00     14769
#
#     accuracy                           1.00     25976
#    macro avg       1.00      1.00      1.00     25976
# weighted avg       1.00      1.00      1.00     25976
